# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df1=pd.read_csv('/content/drive/MyDrive/DrSalehan/orthogonalized.csv')
df1
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x_x  len_x_x  sum_response_time  \
# 0                 0             0               1       19        4583.625017
# 1                 1             1               2       13        3868.552096
# 2                 2             2               3       19        5684.513669
# 3                 3             3               4       10        1733.549571
# 4                 4             4               5       23        5417.119383
# ...             ...           ...             ...      ...                ...
# 1382573     1382573       1383515         1383516       23        3989.190337
# 1382574     1382574       1383516         1383517       22        5748.421274
# 1382575     1382575       1383517         1383518       17        2104.078674
# 1382576     1382576       1383518         1383519       24        3357.209007
# 1382577     1382577       1383519         1383520       11        2597.607287
#
# ...

# %%
#this is last step
df=pd.read_csv('/content/drive/MyDrive/DrSalehan/NewTweets.csv')
df
# Out:
#          Unnamed: 0.1  Unnamed: 0_x_x  Conversation_id_x  Author_id_x  \
# 0                   0               1       1.524918e+18    2836421.0
# 1                   1               2       1.511412e+18    1367531.0
# 2                   2               3       1.511406e+18    1367531.0
# 3                   3               4       1.511407e+18    1367531.0
# 4                   4               5       1.511408e+18    1367531.0
# ...               ...             ...                ...          ...
# 1382573       1383515         1383516       1.666551e+17    2836421.0
# 1382574       1383516         1383517       1.665653e+17    2836421.0
# 1382575       1383517         1383518       1.665436e+17    2836421.0
# 1382576       1383518         1383519       1.663623e+17    2836421.0
# 1382577       1383519         1383520       1.671021e+17    1367531.0
#
#                                                    Tweet_x  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# ...

# %%
column_names = result.columns.tolist()
print(column_names)
# Out:
# ['Unnamed: 0_x_x_x', 'Conversation_id_x', 'Author_id_x', 'Tweet_x', 'Tweets_x_x', 'Retweet_x', 'len_x_x_x', 'sum_arousal_x', 'mean_arousal_x', 'len_orthogonalized_x', 'sum_arousal_orthogonalized_x', 'mean_arousal_orthogonalized_x', 'sum_response_time_x', 'mean_response_time_x', 'Unnamed: 0_y', 'Conversation_id_y', 'Author_id_y', 'Tweet_y', 'Tweets_y', 'Retweet_y', 'len_y', 'sum_arousal_y', 'mean_arousal_y', 'len_orthogonalized_y', 'sum_arousal_orthogonalized_y', 'mean_arousal_orthogonalized_y', 'Segment', 'WC', 'Analytic', 'Clout', 'Authentic', 'Tone', 'WPS', 'BigWords', 'Dic', 'Linguistic', 'function', 'pronoun', 'ppron', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'det', 'article', 'number', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'quantity', 'Drives', 'affiliation', 'achieve', 'power', 'Cognition', 'allnone', 'cogproc', 'insight', 'cause', 'discrep', 'tentat', 'certitude', 'differ', 'memory', 'Affect', 'tone_pos', 'tone_neg', 'emotion', 'emo_pos', 'emo_neg', 
# ...

# %%
df.set_index(df.columns[0],inplace=True)
df
# Out:
#               Unnamed: 0_x_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                          1       1.524918e+18    2836421.0
# 1                          2       1.511412e+18    1367531.0
# 2                          3       1.511406e+18    1367531.0
# 3                          4       1.511407e+18    1367531.0
# 4                          5       1.511408e+18    1367531.0
# ...                      ...                ...          ...
# 1383515              1383516       1.666551e+17    2836421.0
# 1383516              1383517       1.665653e+17    2836421.0
# 1383517              1383518       1.665436e+17    2836421.0
# 1383518              1383519       1.663623e+17    2836421.0
# 1383519              1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# 1             NYC mayor using Florida billboards in attempt ...
# ...

# %%
df1.set_index(df1.columns[1],inplace=True)
df1
# Out:
#               Unnamed: 0  Unnamed: 0_x_x  len_x_x  sum_response_time  \
# Unnamed: 0.1
# 0                      0               1       19        4583.625017
# 1                      1               2       13        3868.552096
# 2                      2               3       19        5684.513669
# 3                      3               4       10        1733.549571
# 4                      4               5       23        5417.119383
# ...                  ...             ...      ...                ...
# 1383515          1382573         1383516       23        3989.190337
# 1383516          1382574         1383517       22        5748.421274
# 1383517          1382575         1383518       17        2104.078674
# 1383518          1382576         1383519       24        3357.209007
# 1383519          1382577         1383520       11        2597.607287
#
#               mean_response_time  sum_response_time_orthogonalized  \
# Unnamed: 0.1
# ...

# %%
result = pd.merge(df, df1, left_index=True, right_index=True)
result
# Out:
#               Unnamed: 0_x_x_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                            1       1.524918e+18    2836421.0
# 1                            2       1.511412e+18    1367531.0
# 2                            3       1.511406e+18    1367531.0
# 3                            4       1.511407e+18    1367531.0
# 4                            5       1.511408e+18    1367531.0
# ...                        ...                ...          ...
# 1383515                1383516       1.666551e+17    2836421.0
# 1383516                1383517       1.665653e+17    2836421.0
# 1383517                1383518       1.665436e+17    2836421.0
# 1383518                1383519       1.663623e+17    2836421.0
# 1383519                1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# ...

# %%
selected_columns = ['sum_response_time_x', 'mean_response_time_x','sum_response_time_y', 'mean_response_time_y']
selected_data = result[selected_columns]

selected_data
# Out:
#               sum_response_time_x  mean_response_time_x  sum_response_time_y  \
# Unnamed: 0.1
# 0                     4583.625017            241.243422          4583.625017
# 1                     3868.552096            297.580930          3868.552096
# 2                     5684.513669            299.184930          5684.513669
# 3                     1733.549571            173.354957          1733.549571
# 4                     5417.119383            235.526930          5417.119383
# ...                           ...                   ...                  ...
# 1383515               3989.190337            173.443058          3989.190337
# 1383516               5748.421274            261.291876          5748.421274
# 1383517               2104.078674            123.769334          2104.078674
# 1383518               3357.209007            139.883709          3357.209007
# 1383519               2597.607287            236.146117          2597.607287
#
# ...

# %%
columns_to_drop = ['sum_response_time_y', 'mean_response_time_y']
result.drop(columns_to_drop, axis=1, inplace=True)
result
# Out:
#               Unnamed: 0_x_x_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                            1       1.524918e+18    2836421.0
# 1                            2       1.511412e+18    1367531.0
# 2                            3       1.511406e+18    1367531.0
# 3                            4       1.511407e+18    1367531.0
# 4                            5       1.511408e+18    1367531.0
# ...                        ...                ...          ...
# 1383515                1383516       1.666551e+17    2836421.0
# 1383516                1383517       1.665653e+17    2836421.0
# 1383517                1383518       1.665436e+17    2836421.0
# 1383518                1383519       1.663623e+17    2836421.0
# 1383519                1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# ...

# %%
result.to_csv('/content/drive/MyDrive/DrSalehan/NewTweets.csv')

# %%
result
# Out:
#               Unnamed: 0_x_x_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                            1       1.524918e+18    2836421.0
# 1                            2       1.511412e+18    1367531.0
# 2                            3       1.511406e+18    1367531.0
# 3                            4       1.511407e+18    1367531.0
# 4                            5       1.511408e+18    1367531.0
# ...                        ...                ...          ...
# 1383515                1383516       1.666551e+17    2836421.0
# 1383516                1383517       1.665653e+17    2836421.0
# 1383517                1383518       1.665436e+17    2836421.0
# 1383518                1383519       1.663623e+17    2836421.0
# 1383519                1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# ...

# %%
#this should be last step
df1=pd.read_csv('/content/drive/MyDrive/DrSalehan/vadercolumns.csv')
df1
# Out:
#          Unnamed: 0.1  Unnamed: 0_x  \
# 0                   0             1
# 1                   1             2
# 2                   2             3
# 3                   3             4
# 4                   4             5
# ...               ...           ...
# 1382573       1383515       1383516
# 1382574       1383516       1383517
# 1382575       1383517       1383518
# 1382576       1383518       1383519
# 1382577       1383519       1383520
#
#                                                   Tweets_x  len_x  vader_neg  \
# 0         thereidout blog karine jean pierre can do wha...     19      0.000
# 1        nyc mayor using florida billboards in attempt ...     13      0.000
# 2        sen hagerty china cartels partnering to create...     19      0.000
# 3                these are america favorite pickup trucks      10      0.000
# 4        watch live president biden vice president harr...     23      0.000
# ...

# %%
df1.set_index(df1.columns[0],inplace=True)
df1
# Out:
#               Unnamed: 0_x                                           Tweets_x  \
# Unnamed: 0.1
# 0                        1   thereidout blog karine jean pierre can do wha...
# 1                        2  nyc mayor using florida billboards in attempt ...
# 2                        3  sen hagerty china cartels partnering to create...
# 3                        4          these are america favorite pickup trucks
# 4                        5  watch live president biden vice president harr...
# ...                    ...                                                ...
# 1383515            1383516  eastwood sb46 ad for chrysler turning into pol...
# 1383516            1383517  chrysler eastwood is leading our viewer vote o...
# 1383517            1383518   superbowl breaks twitter record sorry tebow h...
# 1383518            1383519   here weego broderick broderick which superbow...
# 1383519            1383520  romney expected to speak soon watch live http ...
#
# ...

# %%
df.set_index(df.columns[0],inplace=True)
df
# Out:
#               Unnamed: 0_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                        1       1.524918e+18    2836421.0
# 1                        2       1.511412e+18    1367531.0
# 2                        3       1.511406e+18    1367531.0
# 3                        4       1.511407e+18    1367531.0
# 4                        5       1.511408e+18    1367531.0
# ...                    ...                ...          ...
# 1383515            1383516       1.666551e+17    2836421.0
# 1383516            1383517       1.665653e+17    2836421.0
# 1383517            1383518       1.665436e+17    2836421.0
# 1383518            1383519       1.663623e+17    2836421.0
# 1383519            1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# 1             NYC mayor using Florida billboards in attempt ...
# ...

# %%
df.set_index(df.columns[0],inplace=True)
df
# Out:
#               Unnamed: 0_x_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                          1       1.524918e+18    2836421.0
# 1                          2       1.511412e+18    1367531.0
# 2                          3       1.511406e+18    1367531.0
# 3                          4       1.511407e+18    1367531.0
# 4                          5       1.511408e+18    1367531.0
# ...                      ...                ...          ...
# 1383515              1383516       1.666551e+17    2836421.0
# 1383516              1383517       1.665653e+17    2836421.0
# 1383517              1383518       1.665436e+17    2836421.0
# 1383518              1383519       1.663623e+17    2836421.0
# 1383519              1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# 1             NYC mayor using Florida billboards in attempt ...
# ...

# %%
df1.set_index(df1.columns[0],inplace=True)
df1
# Out:
#             Unnamed: 0.1  Unnamed: 0_x_x  len_x_x  sum_response_time  \
# Unnamed: 0
# 0                      0               1       19        4583.625017
# 1                      1               2       13        3868.552096
# 2                      2               3       19        5684.513669
# 3                      3               4       10        1733.549571
# 4                      4               5       23        5417.119383
# ...                  ...             ...      ...                ...
# 1382573          1383515         1383516       23        3989.190337
# 1382574          1383516         1383517       22        5748.421274
# 1382575          1383517         1383518       17        2104.078674
# 1382576          1383518         1383519       24        3357.209007
# 1382577          1383519         1383520       11        2597.607287
#
#             mean_response_time  sum_response_time_orthogonalized  \
# Unnamed: 0
# ...

# %%
result = pd.merge(df, df1, left_index=True, right_index=True)

# %%
result
# Out:
#               Unnamed: 0_x_x_x  Conversation_id_x  Author_id_x  \
# Unnamed: 0.1
# 0                            1       1.524918e+18    2836421.0
# 1                            2       1.511412e+18    1367531.0
# 2                            3       1.511406e+18    1367531.0
# 3                            4       1.511407e+18    1367531.0
# 4                            5       1.511408e+18    1367531.0
# ...                        ...                ...          ...
# 1383515                1383516       1.666551e+17    2836421.0
# 1383516                1383517       1.665653e+17    2836421.0
# 1383517                1383518       1.665436e+17    2836421.0
# 1383518                1383519       1.663623e+17    2836421.0
# 1383519                1383520       1.671021e+17    1367531.0
#
#                                                         Tweet_x  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# ...

# %%
selected_columns = ['Unnamed: 0_x_x_x', 'len_x_x_x', 'sum_arousal_x', 'mean_arousal_x']
df5 = result[selected_columns].copy()
df5
# Out:
#               Unnamed: 0_x_x_x  len_x_x_x  sum_arousal_x  mean_arousal_x
# Unnamed: 0.1
# 0                            1         19          22.77        1.751538
# 1                            2         13          17.27        1.727000
# 2                            3         19          25.58        1.967692
# 3                            4         10           8.25        1.375000
# 4                            5         23          41.89        2.327222
# ...                        ...        ...            ...             ...
# 1383515                1383516         23          18.93        1.262000
# 1383516                1383517         22           8.62        0.507059
# 1383517                1383518         17           7.92        0.792000
# 1383518                1383519         24           3.33        0.237857
# 1383519                1383520         11          12.27        1.227000
#
# [1382578 rows x 4 columns]

# %%
#this should be last step
df5.to_csv("/content/drive/MyDrive/DrSalehan/sampledata.csv")

# %%
df=pd.read_csv('/content/drive/MyDrive/DrSalehan/data0712.csv')
df
# Out:
# <ipython-input-3-96e6d9cd9104>:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/drive/MyDrive/DrSalehan/data0712.csv')
#          Unnamed: 0  Conversation_id  Author_id  \
# 0                 1     1.524918e+18  2836421.0
# 1                 2     1.511412e+18  1367531.0
# 2                 3     1.511406e+18  1367531.0
# 3                 4     1.511407e+18  1367531.0
# 4                 5     1.511408e+18  1367531.0
# ...             ...              ...        ...
# 1383515     1383516     1.666551e+17  2836421.0
# 1383516     1383517     1.665653e+17  2836421.0
# 1383517     1383518     1.665436e+17  2836421.0
# 1383518     1383519     1.663623e+17  2836421.0
# 1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Conversation_id', 'Author_id', 'Tweet', 'Tweets',
#        'Retweet', 'Language', 'Time_created', 'Date', 'Time', 'Reply', 'Like',
#        'Quote', 'Source', 'Sensitive', 'User_name', 'URL', 'len', 'hashtag',
#        'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'vader_isnegative', 'vader_ispositive', 'vader_isneutral',
#        'anew_sum_valence', 'anew_sum_arousal', 'anew_sum_dominance',
#        'anew_mean_valence', 'anew_mean_arousal', 'anew_mean_dominance',
#        'anger', 'anticipation', 'joy', 'trust', 'fear', 'negative', 'sadness',
#        'surprise', 'disgust', 'anger_norm', 'anticipation_norm', 'joy_norm',
#        'trust_norm', 'fear_norm', 'negative_norm', 'sadness_norm',
#        'surprise_norm', 'disgust_norm', 'sum_response_time',
#        'mean_response_time', 'vader_total_sentiment', 'vader_polarity',
#        'vader_compound_X_vader_isnegative', 'vader_total_sentiment_norm',
# ...

# %%
df['norm_len'] = df.Tweets.apply(lambda x: len(x.split()))
df.head(2)
# Out:
#    Unnamed: 0  Conversation_id  Author_id  \
# 0           1     1.524918e+18  2836421.0
# 1           2     1.511412e+18  1367531.0
#
#                                                Tweet  \
# 0  .@thereidout Blog: Karine Jean-Pierre can do w...
# 1  NYC mayor using Florida billboards in attempt ...
#
#                                               Tweets  Retweet Language  \
# 0   thereidout blog karine jean pierre can do wha...       16       en
# 1  nyc mayor using florida billboards in attempt ...       24       en
#
#                 Time_created        Date      Time  ...  Retweet.Normalized  \
# 0  2022-05-13 01:02:06+00:00  2022-05-13  01:02:06  ...                  17
# 1  2022-04-05 18:35:00+00:00  2022-04-05  18:35:00  ...                  25
#
#    vaderXvader_isnegativeXarousal_mean  vaderXvader_isnegativeXarousal_sum  \
# 0                                  0.0                                 0.0
# ...

# %%
anew = pd.read_csv('/content/drive/MyDrive/ANEW_EnglishShortened.csv').set_index('Word')
print(anew.shape)
anew.head()
# Out:
# (13915, 3)
#              valence  arousal  dominance
# Word
# aardvark        6.26     2.41       4.27
# abalone         5.30     2.65       4.95
# abandon         2.84     3.73       3.32
# abandonment     2.63     4.95       2.64
# abbey           5.85     2.20       5.00

# %%
df['sum_arousal'] = df['Tweets'].apply(lambda x: np.sum([anew.loc[w, 'arousal'] for w in x.split() if w in anew.index]))
df['mean_arousal'] = df['sum_arousal'] / df['norm_len']
df.fillna(0, inplace=True)
df.head(2)
# Out:
#    Unnamed: 0  Conversation_id  Author_id  \
# 0           1     1.524918e+18  2836421.0
# 1           2     1.511412e+18  1367531.0
#
#                                                Tweet  \
# 0  .@thereidout Blog: Karine Jean-Pierre can do w...
# 1  NYC mayor using Florida billboards in attempt ...
#
#                                               Tweets  Retweet Language  \
# 0   thereidout blog karine jean pierre can do wha...       16       en
# 1  nyc mayor using florida billboards in attempt ...       24       en
#
#                 Time_created        Date      Time  ...  \
# 0  2022-05-13 01:02:06+00:00  2022-05-13  01:02:06  ...
# 1  2022-04-05 18:35:00+00:00  2022-04-05  18:35:00  ...
#
#    vaderXvader_isnegativeXarousal_sum   log_len  oArousal_len oArousal_loglen  \
# 0                                 0.0  2.944439      4.157545       -2.411570
# 1                                 0.0  2.564949      4.535162       -4.666081
#
# ...

# %%
columns_to_keep = ['Unnamed: 0', 'Conversation_id', 'Author_id', 'Tweet', 'Tweets', 'Retweet', 'len', 'sum_arousal', 'mean_arousal']
new_df = df[columns_to_keep].copy()
new_df
# Out:
#          Unnamed: 0  Conversation_id  Author_id  \
# 0                 1     1.524918e+18  2836421.0
# 1                 2     1.511412e+18  1367531.0
# 2                 3     1.511406e+18  1367531.0
# 3                 4     1.511407e+18  1367531.0
# 4                 5     1.511408e+18  1367531.0
# ...             ...              ...        ...
# 1383515     1383516     1.666551e+17  2836421.0
# 1383516     1383517     1.665653e+17  2836421.0
# 1383517     1383518     1.665436e+17  2836421.0
# 1383518     1383519     1.663623e+17  2836421.0
# 1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# 2        Sen. Hagerty: China, cartels partnering to cre...
# 3        These are America's favorite pickup trucks htt...
# 4        WATCH LIVE: President Biden, Vice President Ha...
# ...

# %%
df1=pd.read_csv('/content/drive/MyDrive/DrSalehan/new_data0712-2.csv')
df1
# Out:
#          Unnamed: 0.1  Unnamed: 0  Conversation_id  Author_id  \
# 0                   0           1     1.524918e+18  2836421.0
# 1                   1           2     1.511412e+18  1367531.0
# 2                   2           3     1.511406e+18  1367531.0
# 3                   3           4     1.511407e+18  1367531.0
# 4                   4           5     1.511408e+18  1367531.0
# ...               ...         ...              ...        ...
# 1383515       1383515     1383516     1.666551e+17  2836421.0
# 1383516       1383516     1383517     1.665653e+17  2836421.0
# 1383517       1383517     1383518     1.665436e+17  2836421.0
# 1383518       1383518     1383519     1.663623e+17  2836421.0
# 1383519       1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
df2=pd.read_csv("/content/drive/MyDrive/DrSalehan/LIWC-22 Results - new_data0712 - LIWC Analysis.csv")
df2
# Out:
#          Unnamed: 0.1  Unnamed: 0  Conversation_id  Author_id  \
# 0                   0           1     1.524918e+18  2836421.0
# 1                   1           2     1.511412e+18  1367531.0
# 2                   2           3     1.511406e+18  1367531.0
# 3                   3           4     1.511407e+18  1367531.0
# 4                   4           5     1.511408e+18  1367531.0
# ...               ...         ...              ...        ...
# 1382573       1383515     1383516     1.666551e+17  2836421.0
# 1382574       1383516     1383517     1.665653e+17  2836421.0
# 1382575       1383517     1383518     1.665436e+17  2836421.0
# 1382576       1383518     1383519     1.663623e+17  2836421.0
# 1382577       1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# Conversation_id    0
# Author_id          0
# Tweet              0
#                   ..
# QMark              0
# Exclam             0
# Apostro            0
# OtherP             0
# Emoji              0
# Length: 132, dtype: int64

# %%
df2.set_index(df2.columns[0],inplace=True)

# %%
 146 -132
# Out:
# 14

# %%
result = pd.merge(df1, df2, left_index=True, right_index=True)

# %%
result
# Out:
#          Unnamed: 0.1  Unnamed: 0_x  Conversation_id_x  Author_id_x  \
# 0                   0             1       1.524918e+18    2836421.0
# 1                   1             2       1.511412e+18    1367531.0
# 2                   2             3       1.511406e+18    1367531.0
# 3                   3             4       1.511407e+18    1367531.0
# 4                   4             5       1.511408e+18    1367531.0
# ...               ...           ...                ...          ...
# 1383515       1383515       1383516       1.666551e+17    2836421.0
# 1383516       1383516       1383517       1.665653e+17    2836421.0
# 1383517       1383517       1383518       1.665436e+17    2836421.0
# 1383518       1383518       1383519       1.663623e+17    2836421.0
# 1383519       1383519       1383520       1.671021e+17    1367531.0
#
#                                                    Tweet_x  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# ...

# %%
1382578-1383520
# Out:
# -942

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0.1                     0
# Unnamed: 0                       0
# Conversation_id                  0
# Author_id                        0
# Tweet                            0
# Tweets                           0
# Retweet                          0
# len                              0
# sum_arousal                      0
# mean_arousal                     0
# len_orthogonalized               0
# sum_arousal_orthogonalized       0
# mean_arousal_orthogonalized      0
# sum_response_time              925
# mean_response_time             925
# dtype: int64

# %%
result.isna().sum()
# Out:
# Unnamed: 0.1         0
# Unnamed: 0_x         0
# Conversation_id_x    0
# Author_id_x          0
# Tweet_x              0
#                     ..
# QMark                0
# Exclam               0
# Apostro              0
# OtherP               0
# Emoji                0
# Length: 146, dtype: int64

# %%
x=result.isna().sum()
x[x>0]
# Out:
# sum_response_time        925
# mean_response_time       925
# Analytic               61744
# Clout                 438323
# Authentic             151822
# Tone                  604208
# dtype: int64

# %%
df2.shape
# Out:
# (1382578, 131)

# %%
result.shape
# Out:
# (1382578, 146)

# %%
result.to_csv("/content/drive/MyDrive/DrSalehan/NewTweets.csv", index=False)

# %%
df2.shape[0]-df1.shape[0]
# Out:
# -942

# %%
desired_columns = ['len', 'sum_arousal', 'mean_arousal', 'sum_response_time', 'mean_response_time']
df2 = df1.loc[:, desired_columns]
df2
# Out:
#          len  sum_arousal  mean_arousal  sum_response_time  mean_response_time
# 0         19        22.77      1.751538        4583.625017          241.243422
# 1         13        17.27      1.727000        3868.552096          297.580930
# 2         19        25.58      1.967692        5684.513669          299.184930
# 3         10         8.25      1.375000        1733.549571          173.354957
# 4         23        41.89      2.327222        5417.119383          235.526930
# ...      ...          ...           ...                ...                 ...
# 1383515   23        18.93      1.262000        3989.190337          173.443058
# 1383516   22         8.62      0.507059        5748.421274          261.291876
# 1383517   17         7.92      0.792000        2104.078674          123.769334
# 1383518   24         3.33      0.237857        3357.209007          139.883709
# 1383519   11        12.27      1.227000        2597.607287          236.146117
#
# ...

# %%
A = df2.values

# %%
df2.to_csv('/content/drive/MyDrive/DrSalehan/runorthogonalized.csv')

# %%
columns_to_orthogonalize = ['sum_arousal', 'mean_arousal', 'sum_response_time', 'mean_response_time']

# %%
orthogonalized_array = modified_gs(A, column_indices)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-176-b7b550433654> in <cell line: 1>()
# ----> 1 orthogonalized_array = modified_gs(A, column_indices)
#
# <ipython-input-172-77b6fb20790e> in modified_gs(A, columns_indices)
#       4
#       5     # Calculate the norm of the 'len' column
# ----> 6     L = np.sqrt(np.sum(A[:, 7] ** 2))
#       7
#       8     # Normalize the data
#
# IndexError: index 7 is out of bounds for axis 1 with size 5

# %%
print(df1.columns)
print(len(df1.columns))
print(column_indices)
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Conversation_id', 'Author_id', 'Tweet',
#        'Tweets', 'Retweet', 'len', 'sum_arousal', 'mean_arousal',
#        'sum_response_time', 'mean_response_time', 'sum_arousal_orthogonalized',
#        'mean_arousal_orthogonalized', 'sum_response_time_orthogonalized',
#        'mean_response_time_orthogonalized'],
#       dtype='object')
# 16
# [7, 8, 9, 10, 11]

# %%
for i, column_name in enumerate(columns_to_orthogonalize):
    df1[column_name + '_orthogonalized'] = orthogonalized_array[:, i]

# %%
df1
# Out:
#          Unnamed: 0.1  Unnamed: 0  Conversation_id  Author_id  \
# 0                   0           1     1.524918e+18  2836421.0
# 1                   1           2     1.511412e+18  1367531.0
# 2                   2           3     1.511406e+18  1367531.0
# 3                   3           4     1.511407e+18  1367531.0
# 4                   4           5     1.511408e+18  1367531.0
# ...               ...         ...              ...        ...
# 1383515       1383515     1383516     1.666551e+17  2836421.0
# 1383516       1383516     1383517     1.665653e+17  2836421.0
# 1383517       1383517     1383518     1.665436e+17  2836421.0
# 1383518       1383518     1383519     1.663623e+17  2836421.0
# 1383519       1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
df1.to_csv("/content/drive/MyDrive/DrSalehan/orthogonalizeTweets.csv", index=False)

# %%
columns_to_orthogonalize_names = ['sum_response_time', 'mean_response_time', 'sum_arousal', 'mean_arousal', 'len']

# %%
A = df1.values

# %%
columns_to_orthogonalize = [df1.columns.get_loc(name) for name in columns_to_orthogonalize_names]

# %%
def modified_gs(A: np.ndarray, columns_indices: list) -> np.ndarray:
    num_vecs = A.shape[0]
    num_dims = len(columns_indices)

    L = np.zeros(num_vecs)
    for i in range(num_vecs):
        L[i] = np.sqrt(np.sum(A[i, columns_indices] ** 2))

    V = A.copy()
    V[:, columns_indices] /= L[:, np.newaxis]

    B = V.copy()
    for j in range(num_dims):
        B[:, columns_indices[j]] /= np.sqrt(np.sum(B[:, columns_indices[j]] ** 2))
        for k in range(j + 1, num_dims):
            B[:, columns_indices[k]] -= np.dot(B[:, columns_indices[j]], V[:, columns_indices[k]]) * B[:, columns_indices[j]]

    return B

# %%
result = modified_gs(A, columns_to_orthogonalize)

# %%
result
# Out:
# array([[0, 1, 1.524917871553413e+18, ..., nan, nan, nan],
#        [1, 2, 1.5114121011258368e+18, ..., nan, nan, nan],
#        [2, 3, 1.5114058095272714e+18, ..., nan, nan, nan],
#        ...,
#        [1383517, 1383518, 1.665436e+17, ..., nan, nan, nan],
#        [1383518, 1383519, 1.663623e+17, ..., nan, nan, nan],
#        [1383519, 1383520, 1.671021e+17, ..., nan, nan, nan]], dtype=object)

# %%
df1[columns_to_orthogonalize_names] = result[:, columns_to_orthogonalize]

# %%
df1
# Out:
#          Unnamed: 0.1  Unnamed: 0  Conversation_id  Author_id  \
# 0                   0           1     1.524918e+18  2836421.0
# 1                   1           2     1.511412e+18  1367531.0
# 2                   2           3     1.511406e+18  1367531.0
# 3                   3           4     1.511407e+18  1367531.0
# 4                   4           5     1.511408e+18  1367531.0
# ...               ...         ...              ...        ...
# 1383515       1383515     1383516     1.666551e+17  2836421.0
# 1383516       1383516     1383517     1.665653e+17  2836421.0
# 1383517       1383517     1383518     1.665436e+17  2836421.0
# 1383518       1383518     1383519     1.663623e+17  2836421.0
# 1383519       1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
A = df1.values

# %%
columns_to_orthogonalize = [columns.index(name) for name in columns_to_orthogonalize_names]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-eb8bb62134b6> in <cell line: 1>()
# ----> 1 columns_to_orthogonalize = [columns.index(name) for name in columns_to_orthogonalize_names]
#
# <ipython-input-33-eb8bb62134b6> in <listcomp>(.0)
# ----> 1 columns_to_orthogonalize = [columns.index(name) for name in columns_to_orthogonalize_names]
#
# ValueError: 7 is not in list

# %%
def modified_gs(A: np.ndarray, columns_indices: list) -> np.ndarray:
    num_vecs = A.shape[0]
    num_dims = len(columns_indices)

    L = np.zeros(num_vecs)
    for i in range(num_vecs):
        L[i] = np.sqrt(np.sum(A[i, columns_indices] ** 2))

    V = A.copy()
    V[:, columns_indices] /= L[:, np.newaxis]

    B = V.copy()
    for j in range(num_dims):
        B[:, columns_indices[j]] /= np.sqrt(np.sum(B[:, columns_indices[j]] ** 2))
        for k in range(j + 1, num_dims):
            B[:, columns_indices[k]] -= np.dot(B[:, columns_indices[j]], V[:, columns_indices[k]]) * B[:, columns_indices[j]]

    return B

# %%
result = modified_gs(A, columns_to_orthogonalize)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-04c7f7b19f8f> in <cell line: 1>()
# ----> 1 result = modified_gs(A, columns_to_orthogonalize)
#
# <ipython-input-23-c286ec68bd20> in modified_gs(A, columns_indices)
#       5     L = np.zeros(num_vecs)
#       6     for i in range(num_vecs):
# ----> 7         L[i] = np.sqrt(np.sum(A[i, columns_indices] ** 2))
#       8
#       9     V = A.copy()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df1[columns_to_orthogonalize] = result[:, columns_to_orthogonalize]

# %%
def modified_gs(A: np.ndarray, columns_indices: list) -> np.ndarray:
    num_vecs = A.shape[0]
    num_dims = len(columns_indices)

    L = np.zeros(num_vecs)
    for i in range(num_vecs):
        L[i] = np.sqrt(np.sum(A[i, columns_indices] ** 2))

    V = A.copy()
    V[:, columns_indices] /= L[:, np.newaxis]

    B = V.copy()
    for j in range(num_dims):
        B[:, columns_indices[j]] /= np.sqrt(np.sum(B[:, columns_indices[j]] ** 2))
        for k in range(j + 1, num_dims):
            B[:, columns_indices[k]] -= np.dot(B[:, columns_indices[j]], V[:, columns_indices[k]]) * B[:, columns_indices[j]]

    return B

# %%
A = new_df[['len', 'sum_arousal', 'mean_arousal','sum_response_time', 'mean_response_time']].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-ccb0d4faf0b4> in <cell line: 1>()
# ----> 1 A = new_df[['len', 'sum_arousal', 'mean_arousal','sum_response_time', 'mean_response_time']].to_numpy()
#
# NameError: name 'new_df' is not defined

# %%
column_indices = [0, 1, 2]

# %%
orthogonalized_array = modified_gs(A, column_indices)

# %%
for i, column_name in enumerate(['len_orthogonalized', 'sum_arousal_orthogonalized', 'mean_arousal_orthogonalized']):
    new_df[column_name] = orthogonalized_array[:, i]

# %%
new_df
# Out:
#          Unnamed: 0  Conversation_id  Author_id  \
# 0                 1     1.524918e+18  2836421.0
# 1                 2     1.511412e+18  1367531.0
# 2                 3     1.511406e+18  1367531.0
# 3                 4     1.511407e+18  1367531.0
# 4                 5     1.511408e+18  1367531.0
# ...             ...              ...        ...
# 1383515     1383516     1.666551e+17  2836421.0
# 1383516     1383517     1.665653e+17  2836421.0
# 1383517     1383518     1.665436e+17  2836421.0
# 1383518     1383519     1.663623e+17  2836421.0
# 1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# 2        Sen. Hagerty: China, cartels partnering to cre...
# 3        These are America's favorite pickup trucks htt...
# 4        WATCH LIVE: President Biden, Vice President Ha...
# ...

# %%
df2=pd.read_csv('/content/drive/MyDrive/DrSalehan/LIWC-22 Results - new_data0712 - LIWC Analysis.csv')
df2
# Out:
#          Unnamed: 0.1  Unnamed: 0  Conversation_id  Author_id  \
# 0                   0           1     1.524918e+18  2836421.0
# 1                   1           2     1.511412e+18  1367531.0
# 2                   2           3     1.511406e+18  1367531.0
# 3                   3           4     1.511407e+18  1367531.0
# 4                   4           5     1.511408e+18  1367531.0
# ...               ...         ...              ...        ...
# 1382573       1383515     1383516     1.666551e+17  2836421.0
# 1382574       1383516     1383517     1.665653e+17  2836421.0
# 1382575       1383517     1383518     1.665436e+17  2836421.0
# 1382576       1383518     1383519     1.663623e+17  2836421.0
# 1382577       1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
for column in df2.columns:
    print(column)
# Out:
# Unnamed: 0.1
# Unnamed: 0
# Conversation_id
# Author_id
# Tweet
# Tweets
# Retweet
# len
# sum_arousal
# mean_arousal
# len_orthogonalized
# sum_arousal_orthogonalized
# mean_arousal_orthogonalized
# Segment
# WC
# Analytic
# Clout
# Authentic
# Tone
# WPS
# BigWords
# Dic
# Linguistic
# function
# pronoun
# ppron
# i
# we
# you
# shehe
# they
# ipron
# det
# article
# number
# prep
# auxverb
# adverb
# conj
# negate
# verb
# adj
# quantity
# Drives
# affiliation
# achieve
# power
# Cognition
# allnone
# cogproc
# insight
# cause
# discrep
# tentat
# certitude
# differ
# memory
# Affect
# tone_pos
# tone_neg
# emotion
# emo_pos
# emo_neg
# emo_anx
# emo_anger
# emo_sad
# swear
# Social
# socbehav
# prosocial
# polite
# conflict
# moral
# comm
# socrefs
# family
# friend
# female
# male
# Culture
# politic
# ethnicity
# tech
# Lifestyle
# leisure
# home
# work
# money
# relig
# Physical
# health
# illness
# wellness
# mental
# substances
# sexual
# food
# death
# need
# want
# ...

# %%
df1=pd.read_csv('/content/drive/MyDrive/DrSalehan/new_data0712-2.csv')
df1
# Out:
#          Unnamed: 0.1  Unnamed: 0  Conversation_id  Author_id  \
# 0                   0           1     1.524918e+18  2836421.0
# 1                   1           2     1.511412e+18  1367531.0
# 2                   2           3     1.511406e+18  1367531.0
# 3                   3           4     1.511407e+18  1367531.0
# 4                   4           5     1.511408e+18  1367531.0
# ...               ...         ...              ...        ...
# 1383515       1383515     1383516     1.666551e+17  2836421.0
# 1383516       1383516     1383517     1.665653e+17  2836421.0
# 1383517       1383517     1383518     1.665436e+17  2836421.0
# 1383518       1383518     1383519     1.663623e+17  2836421.0
# 1383519       1383519     1383520     1.671021e+17  1367531.0
#
#                                                      Tweet  \
# 0        .@thereidout Blog: Karine Jean-Pierre can do w...
# 1        NYC mayor using Florida billboards in attempt ...
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Conversation_id', 'Author_id', 'Tweet',
#        'Tweets', 'Retweet', 'len', 'sum_arousal', 'mean_arousal',
#        'len_orthogonalized', 'sum_arousal_orthogonalized',
#        'mean_arousal_orthogonalized', 'sum_response_time',
#        'mean_response_time'],
#       dtype='object')

# %%
merged_df = df1.merge(df2, on=['Conversation_id', 'Author_id', 'Tweet', 'Tweets', 'Retweet', 'len', 'sum_arousal', 'mean_arousal','len_orthogonalized',
'sum_arousal_orthogonalized','mean_arousal_orthogonalized'], how='left')
merged_df.drop(['Unnamed: 0.1_y', 'Unnamed: 0_y'], axis=1, inplace=True)
merged_df.rename(columns={'Unnamed: 0.1_x': 'Unnamed: 0.1', 'Unnamed: 0_x': 'Unnamed: 0'}, inplace=True)
merged_df.set_index("Unnamed: 0.1", inplace=True)

# %%
merged_df
# Out:
#               Unnamed: 0  Conversation_id  Author_id  \
# Unnamed: 0.1
# 0                      1     1.524918e+18  2836421.0
# 1                      2     1.511412e+18  1367531.0
# 2                      3     1.511406e+18  1367531.0
# 3                      4     1.511407e+18  1367531.0
# 4                      5     1.511408e+18  1367531.0
# ...                  ...              ...        ...
# 1383515          1383516     1.666551e+17  2836421.0
# 1383516          1383517     1.665653e+17  2836421.0
# 1383517          1383518     1.665436e+17  2836421.0
# 1383518          1383519     1.663623e+17  2836421.0
# 1383519          1383520     1.671021e+17  1367531.0
#
#                                                           Tweet  \
# Unnamed: 0.1
# 0             .@thereidout Blog: Karine Jean-Pierre can do w...
# 1             NYC mayor using Florida billboards in attempt ...
# 2             Sen. Hagerty: China, cartels partnering to cre...
# ...

# %%
for column in merged_df.columns:
    print(column)
# Out:
# Unnamed: 0
# Conversation_id
# Author_id
# Tweet
# Tweets
# Retweet
# len
# sum_arousal
# mean_arousal
# len_orthogonalized
# sum_arousal_orthogonalized
# mean_arousal_orthogonalized
# sum_response_time
# mean_response_time
# Segment
# WC
# Analytic
# Clout
# Authentic
# Tone
# WPS
# BigWords
# Dic
# Linguistic
# function
# pronoun
# ppron
# i
# we
# you
# shehe
# they
# ipron
# det
# article
# number
# prep
# auxverb
# adverb
# conj
# negate
# verb
# adj
# quantity
# Drives
# affiliation
# achieve
# power
# Cognition
# allnone
# cogproc
# insight
# cause
# discrep
# tentat
# certitude
# differ
# memory
# Affect
# tone_pos
# tone_neg
# emotion
# emo_pos
# emo_neg
# emo_anx
# emo_anger
# emo_sad
# swear
# Social
# socbehav
# prosocial
# polite
# conflict
# moral
# comm
# socrefs
# family
# friend
# female
# male
# Culture
# politic
# ethnicity
# tech
# Lifestyle
# leisure
# home
# work
# money
# relig
# Physical
# health
# illness
# wellness
# mental
# substances
# sexual
# food
# ...

# %%
merged_df.to_csv("/content/drive/MyDrive/DrSalehan/new_data0712.csv", index=False)

# %%
from nltk.sentiment
import SentimentIntensityAnalyzer
# Out:
#   File "<ipython-input-6-c078bf7b8290>", line 1
#     from nltk.sentiment
#                        ^
# SyntaxError: invalid syntax
